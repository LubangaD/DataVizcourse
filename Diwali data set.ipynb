# %%
import pandas as pd 
import plotly.express as px
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
diwali=pd.read_csv(r"C:\Users\Administrator\Downloads\diwali.csv")
diwali
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
diwali.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
diwali.shape
# Out:
# (11251, 15)

# %%
diwali.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# Columns with missing values

# %%
diwali.columns[np.sum(diwali.isnull()) != 0]
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Index(['Amount', 'Status', 'unnamed1'], dtype='object')

# %%
diwali.dropna(inplace=True)

# %% [markdown]
# Columns without missing values

# %%
diwali.columns[np.sum(diwali.isnull()) == 0]
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders'],
#       dtype='object')

# %% [markdown]
# Top selling product category

# %%
fig=px.bar(diwali,x='Product_Category',y='Amount',color='Zone')
fig.show()

# %% [markdown]
# Occupation that spends the most

# %%
fig=px.histogram(diwali,x='Occupation',y='Amount')
fig.show()

# %%
fig=px.pie(diwali,names='Product_Category')
fig.show()

# %% [markdown]
# Gender thats spends the most amount in each state

# %%
fig=px.box(diwali,x='State',y='Amount',color='Gender')
fig

# %%
diwali.groupby('Age Group').count()['Amount'].plot(kind='bar')
# Out:
# <Axes: xlabel='Age Group'>

# %%
diwali.groupby('State').count()['Product_Category']
# Out:
# State
# Andhra Pradesh       812
# Bihar                434
# Delhi               1107
# Gujarat              429
# Haryana              452
# Himachal Pradesh     608
# Jharkhand            380
# Karnataka           1305
# Kerala               453
# Madhya Pradesh       923
# Maharashtra         1526
# Punjab               200
# Rajasthan            231
# Telangana            125
# Uttar Pradesh       1946
# Uttarakhand          320
# Name: Product_Category, dtype: int64

# %%
diwali.groupby('State').count()['Amount']
# Out:
# State
# Andhra Pradesh       811
# Bihar                434
# Delhi               1104
# Gujarat              427
# Haryana              452
# Himachal Pradesh     608
# Jharkhand            380
# Karnataka           1304
# Kerala               453
# Madhya Pradesh       921
# Maharashtra         1525
# Punjab               200
# Rajasthan            231
# Telangana            125
# Uttar Pradesh       1944
# Uttarakhand          320
# Name: Amount, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.bar(diwali['Orders'],diwali['Amount'],color='black')
plt.xlabel('No of Orders')
plt.ylabel('Total amount')
plt.show()

# %%
fig=px.scatter(diwali,x='Age Group',y='Amount',color='Age')
fig.show()
